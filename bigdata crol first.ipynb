# %%
import matplotlib
import matplotlib.pyplot as plt

x = [2016,2017,2018,2019,2020]
y = [350,410,520,695,543]

plt.plot(x,y)

plt.title('Annual sales')

plt.xlabel('years')

plt.ylabel('sales')

plt.show()

# %%
#네이버 API를 이용한 크롤링

import os
import sys
import urllib.request
client_id = "0KKFh6Cii69eEp1dWM73"
client_secret = "GgCVRePonV"
encText = urllib.parse.quote("챗gpt")
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode == 200):
    response_body = response.read()
    encoded_text = response_body.decode('utf-8')
    print(encoded_text)
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 12 Jun 2023 20:55:37 +0900",
# 	"total":42336,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"&apos;우주소년 아톰&apos; 원작자 故데즈카 오사무 신작, <b>챗GPT<\/b> 활용해 나온다",
# 			"originallink":"https:\/\/www.ajunews.com\/view\/20230612203132516",
# 			"link":"https:\/\/www.ajunews.com\/view\/20230612203132516",
# 			"description":"GPT-4 기술로 &apos;블랙잭&apos; 신작 시나리오 작업 유족 장남 &quot;AI로 인간 창작 돕는 프로젝트&quot; 아주경제=정연우 기자... <b>챗GPT<\/b>의 도움을 받아 제작된다. 12일 교도통신 보도에 따르면 고인의 작품을 학습한 AI와 창작자들이 협업해... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:54:00 +0900"
# 		},
# 		{
# 			"title":"[인터뷰] 우리나라 소방 발전 위해 연구년까지 냈다… 이승철 한국화재소방학...",
# 			"originallink":"http:\/\/fpn119.co.kr\/199165",
# 			"link":"http:\/\/fpn119.co.kr\/199165",
# 			"description":"최근 <b>챗GPT<\/b> 열풍에 따라 인공지능(AI)이 화두다. 사물인터넷(IoT), 빅데이터 등 4차산업혁명을 주도하는 첨단기술은 이미 산업 전반에 깊숙이 침투해 있다. 그러나 국민의 생명과 재산을 책임지는 ‘화재소방’은 빠르게... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:52:00 +0900"
# 		},
# 		{
# 			"title":"데즈카 오사무 만화 &apos;블랙잭&apos; 신작 <b>챗GPT<\/b> 협업으로 나온다",
# 			"originallink":"https:\/\/imnews.imbc.com\/news\/2023\/world\/article\/6492795_36133.html",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/214\/0001278711?sid=104",
# 			"description":"<b>챗GPT<\/b>의 도움을 받아 제작됩니다. 교도통신에 따르면, 고인의 작품을 학습한 AI와 창작자들이 협업해... 고인의 과거 &apos;블랙잭&apos; 작품에서 이야기 구조와 등장인물의 관계 등을 학습한 <b>챗GPT<\/b>의 최신 버전인 GPT-4가... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:40:00 +0900"
# 		},
# 		{
# 			"title":"스마트인재개발원, AI 올인원 실무캠프 교육생 모집",
# 			"originallink":"http:\/\/www.kjdaily.com\/article.php?aid=1686567842604150004",
# 			"link":"http:\/\/www.kjdaily.com\/article.php?aid=1686567842604150004",
# 			"description":"언어지능(GPT·7월4일 개강) 등 분야에 따라 구성됐다. 자율주행과 스마트홈 구현을 위한 실무형 커리큘럼으로 최근 화두가 되고 있는 <b>챗GPT<\/b> 활용부터 기반 기술까지 모두 배울 수 있는 과정이다. 언어지능 실무캠프의... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:20:00 +0900"
# 		},
# 		{
# 			"title":"인공지능 시대 딜레마에 빠진 인류",
# 			"originallink":"http:\/\/www.cctimes.kr\/news\/articleView.html?idxno=755096",
# 			"link":"http:\/\/www.cctimes.kr\/news\/articleView.html?idxno=755096",
# 			"description":"미국의 오픈AI(Open AI)사가 공개한 <b>챗GPT<\/b>(ChatGPT)가 기존의 인공지능과는 차별성을 드러내며 놀라움을 안겨주었기 때문이다. 기존의 구글이 다양한 검색 사례를 열거해 보여줬다면 <b>챗GPT<\/b>는 질문자의 맞춤형 답변이... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:20:00 +0900"
# 		},
# 		{
# 			"title":"상반기 베스트셀러 ‘세이노의 가르침’",
# 			"originallink":"http:\/\/www.kwangju.co.kr\/article.php?aid=1686567600753527026",
# 			"link":"http:\/\/www.kwangju.co.kr\/article.php?aid=1686567600753527026",
# 			"description":"올 상반기에는 <b>챗GPT<\/b>의 열풍도 두드러졌다. 대화형 인공지능에 대한 관심은 관련 도서 출간 등으로 이어졌다. 예스24에 따르면 ‘<b>챗GPT<\/b> : 마침내 찾아온 특이점’, ‘<b>챗GPT<\/b>가 바꿀 우리 인류의 미래’, ‘<b>챗GPT<\/b> 사용설명서’... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:04:00 +0900"
# 		},
# 		{
# 			"title":"[EBN 오늘(12일) 이슈 종합] IPO 시장, 상승장 속 기대만발…청년도약계좌 실...",
# 			"originallink":"https:\/\/www.ebn.co.kr\/news\/view\/1580558\/?sc=Naver",
# 			"link":"https:\/\/www.ebn.co.kr\/news\/view\/1580558\/?sc=Naver",
# 			"description":"연초 <b>챗GPT<\/b> 붐 속 AI 테마에 힘입어 1차 상승기를 맞았던 의료 AI 종목들은 정부 지원과 연이은 계약 체결에 따른 실적 개선으로 평균 약 280%의 주가 상승률을 기록 중이다. [EBN ()]",
# 			"pubDate":"Mon, 12 Jun 2023 20:02:00 +0900"
# 		},
# 		{
# 			"title":"데즈카 오사무 만화 &apos;블랙잭&apos; 신작 <b>챗GPT<\/b> 협업으로 나온다",
# 			"originallink":"https:\/\/www.yna.co.kr\/view\/AKR20230612152100073?input=1195m",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/001\/0013997437?sid=104",
# 			"description":"<b>챗GPT<\/b>의 도움을 받아 제작된다. 12일 교도통신 보도에 따르면 고인의 작품을 학습한 AI와 창작자들이 협업해... 고인의 과거 &apos;블랙잭&apos; 작품에서 이야기 구조와 등장인물의 관계 등을 학습한 <b>챗GPT<\/b>의 최신 버전인 GPT-4가... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:00:00 +0900"
# 		},
# 		{
# 			"title":"최성환 SK네트웍스 사장, &apos;<b>챗 GPT<\/b>&apos; 샘 알트만 만나",
# 			"originallink":"http:\/\/www.newspim.com\/news\/view\/20230612000886",
# 			"link":"http:\/\/www.newspim.com\/news\/view\/20230612000886",
# 			"description":"최성환 SK네트웍스 사업총괄 사장이 &apos;<b>챗GPT<\/b> 아버지&apos; 샘 올트먼 오픈AI CEO(최고경영자)를 만나 AI 기업 투자 협력을 논의했다. 최성환 SK네트웍스 사업총괄 사장. [사진=SK네트웍스] 11일 재계에 따르면 최성환... ",
# 			"pubDate":"Mon, 12 Jun 2023 19:31:00 +0900"
# 		},
# 		{
# 			"title":"AI 전문가 모시기 경쟁 나선 빅테크",
# 			"originallink":"https:\/\/www.aitimes.com\/news\/articleView.html?idxno=151649",
# 			"link":"https:\/\/www.aitimes.com\/news\/articleView.html?idxno=151649",
# 			"description":"&apos;<b>챗GPT<\/b>&apos;를 개발한 오픈AI 역시 20만달러에서 37만달러에 이르는 연봉을 제시하며 정책연구팀에서 근무할 기계학습 전문가를 찾고 있다.  AI 시스템을 시험 및 평가하고, 위험한 기능과 실존적 위험, 공정성 및 표현, 환각... ",
# 			"pubDate":"Mon, 12 Jun 2023 19:28:00 +0900"
# 		}
# 	]
# }

# %%
import os
import sys
import urllib.request
client_id = "0KKFh6Cii69eEp1dWM73"
client_secret = "GgCVRePonV"
encText = urllib.parse.quote("챗gpt")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText 
# XML 결과 request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id) 
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) 
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 12 Jun 2023 20:55:37 +0900",
# 	"total":42336,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"&apos;우주소년 아톰&apos; 원작자 故데즈카 오사무 신작, <b>챗GPT<\/b> 활용해 나온다",
# 			"originallink":"https:\/\/www.ajunews.com\/view\/20230612203132516",
# 			"link":"https:\/\/www.ajunews.com\/view\/20230612203132516",
# 			"description":"GPT-4 기술로 &apos;블랙잭&apos; 신작 시나리오 작업 유족 장남 &quot;AI로 인간 창작 돕는 프로젝트&quot; 아주경제=정연우 기자... <b>챗GPT<\/b>의 도움을 받아 제작된다. 12일 교도통신 보도에 따르면 고인의 작품을 학습한 AI와 창작자들이 협업해... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:54:00 +0900"
# 		},
# 		{
# 			"title":"[인터뷰] 우리나라 소방 발전 위해 연구년까지 냈다… 이승철 한국화재소방학...",
# 			"originallink":"http:\/\/fpn119.co.kr\/199165",
# 			"link":"http:\/\/fpn119.co.kr\/199165",
# 			"description":"최근 <b>챗GPT<\/b> 열풍에 따라 인공지능(AI)이 화두다. 사물인터넷(IoT), 빅데이터 등 4차산업혁명을 주도하는 첨단기술은 이미 산업 전반에 깊숙이 침투해 있다. 그러나 국민의 생명과 재산을 책임지는 ‘화재소방’은 빠르게... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:52:00 +0900"
# 		},
# 		{
# 			"title":"데즈카 오사무 만화 &apos;블랙잭&apos; 신작 <b>챗GPT<\/b> 협업으로 나온다",
# 			"originallink":"https:\/\/imnews.imbc.com\/news\/2023\/world\/article\/6492795_36133.html",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/214\/0001278711?sid=104",
# 			"description":"<b>챗GPT<\/b>의 도움을 받아 제작됩니다. 교도통신에 따르면, 고인의 작품을 학습한 AI와 창작자들이 협업해... 고인의 과거 &apos;블랙잭&apos; 작품에서 이야기 구조와 등장인물의 관계 등을 학습한 <b>챗GPT<\/b>의 최신 버전인 GPT-4가... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:40:00 +0900"
# 		},
# 		{
# 			"title":"스마트인재개발원, AI 올인원 실무캠프 교육생 모집",
# 			"originallink":"http:\/\/www.kjdaily.com\/article.php?aid=1686567842604150004",
# 			"link":"http:\/\/www.kjdaily.com\/article.php?aid=1686567842604150004",
# 			"description":"언어지능(GPT·7월4일 개강) 등 분야에 따라 구성됐다. 자율주행과 스마트홈 구현을 위한 실무형 커리큘럼으로 최근 화두가 되고 있는 <b>챗GPT<\/b> 활용부터 기반 기술까지 모두 배울 수 있는 과정이다. 언어지능 실무캠프의... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:20:00 +0900"
# 		},
# 		{
# 			"title":"인공지능 시대 딜레마에 빠진 인류",
# 			"originallink":"http:\/\/www.cctimes.kr\/news\/articleView.html?idxno=755096",
# 			"link":"http:\/\/www.cctimes.kr\/news\/articleView.html?idxno=755096",
# 			"description":"미국의 오픈AI(Open AI)사가 공개한 <b>챗GPT<\/b>(ChatGPT)가 기존의 인공지능과는 차별성을 드러내며 놀라움을 안겨주었기 때문이다. 기존의 구글이 다양한 검색 사례를 열거해 보여줬다면 <b>챗GPT<\/b>는 질문자의 맞춤형 답변이... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:20:00 +0900"
# 		},
# 		{
# 			"title":"상반기 베스트셀러 ‘세이노의 가르침’",
# 			"originallink":"http:\/\/www.kwangju.co.kr\/article.php?aid=1686567600753527026",
# 			"link":"http:\/\/www.kwangju.co.kr\/article.php?aid=1686567600753527026",
# 			"description":"올 상반기에는 <b>챗GPT<\/b>의 열풍도 두드러졌다. 대화형 인공지능에 대한 관심은 관련 도서 출간 등으로 이어졌다. 예스24에 따르면 ‘<b>챗GPT<\/b> : 마침내 찾아온 특이점’, ‘<b>챗GPT<\/b>가 바꿀 우리 인류의 미래’, ‘<b>챗GPT<\/b> 사용설명서’... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:04:00 +0900"
# 		},
# 		{
# 			"title":"[EBN 오늘(12일) 이슈 종합] IPO 시장, 상승장 속 기대만발…청년도약계좌 실...",
# 			"originallink":"https:\/\/www.ebn.co.kr\/news\/view\/1580558\/?sc=Naver",
# 			"link":"https:\/\/www.ebn.co.kr\/news\/view\/1580558\/?sc=Naver",
# 			"description":"연초 <b>챗GPT<\/b> 붐 속 AI 테마에 힘입어 1차 상승기를 맞았던 의료 AI 종목들은 정부 지원과 연이은 계약 체결에 따른 실적 개선으로 평균 약 280%의 주가 상승률을 기록 중이다. [EBN ()]",
# 			"pubDate":"Mon, 12 Jun 2023 20:02:00 +0900"
# 		},
# 		{
# 			"title":"데즈카 오사무 만화 &apos;블랙잭&apos; 신작 <b>챗GPT<\/b> 협업으로 나온다",
# 			"originallink":"https:\/\/www.yna.co.kr\/view\/AKR20230612152100073?input=1195m",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/001\/0013997437?sid=104",
# 			"description":"<b>챗GPT<\/b>의 도움을 받아 제작된다. 12일 교도통신 보도에 따르면 고인의 작품을 학습한 AI와 창작자들이 협업해... 고인의 과거 &apos;블랙잭&apos; 작품에서 이야기 구조와 등장인물의 관계 등을 학습한 <b>챗GPT<\/b>의 최신 버전인 GPT-4가... ",
# 			"pubDate":"Mon, 12 Jun 2023 20:00:00 +0900"
# 		},
# 		{
# 			"title":"최성환 SK네트웍스 사장, &apos;<b>챗 GPT<\/b>&apos; 샘 알트만 만나",
# 			"originallink":"http:\/\/www.newspim.com\/news\/view\/20230612000886",
# 			"link":"http:\/\/www.newspim.com\/news\/view\/20230612000886",
# 			"description":"최성환 SK네트웍스 사업총괄 사장이 &apos;<b>챗GPT<\/b> 아버지&apos; 샘 올트먼 오픈AI CEO(최고경영자)를 만나 AI 기업 투자 협력을 논의했다. 최성환 SK네트웍스 사업총괄 사장. [사진=SK네트웍스] 11일 재계에 따르면 최성환... ",
# 			"pubDate":"Mon, 12 Jun 2023 19:31:00 +0900"
# 		},
# 		{
# 			"title":"AI 전문가 모시기 경쟁 나선 빅테크",
# 			"originallink":"https:\/\/www.aitimes.com\/news\/articleView.html?idxno=151649",
# 			"link":"https:\/\/www.aitimes.com\/news\/articleView.html?idxno=151649",
# 			"description":"&apos;<b>챗GPT<\/b>&apos;를 개발한 오픈AI 역시 20만달러에서 37만달러에 이르는 연봉을 제시하며 정책연구팀에서 근무할 기계학습 전문가를 찾고 있다.  AI 시스템을 시험 및 평가하고, 위험한 기능과 실존적 위험, 공정성 및 표현, 환각... ",
# 			"pubDate":"Mon, 12 Jun 2023 19:28:00 +0900"
# 		}
# 	]
# }

# %%
#네이버 뉴스 크롤링

import os
import sys
import urllib.request
import datetime
import time
import json

client_id = "0KKFh6Cii69eEp1dWM73"
client_secret = "GgCVRePonV"


#[CODE 1]
def getRequestUrl(url):    
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)
    
    try: 
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print ("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

#[CODE 2]
def getNaverSearch(node, srcText, start, display):    
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % node
    parameters = "?query=%s&start=%s&display=%s" % (urllib.parse.quote(srcText), start, display)
    
    url = base + node + parameters    
    responseDecode = getRequestUrl(url)   #[CODE 1]
    
    if (responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)

#[CODE 3]
def getPostData(post, jsonResult, cnt):    
    title = post['title']
    description = post['description']
    org_link = post['originallink']
    link = post['link']
    
    pDate = datetime.datetime.strptime(post['pubDate'],  '%a, %d %b %Y %H:%M:%S +0900')
    pDate = pDate.strftime('%Y-%m-%d %H:%M:%S')
    
    jsonResult.append({'cnt':cnt, 'title':title, 'description': description, 
'org_link':org_link,   'link': org_link,   'pDate':pDate})
    return    

#[CODE 0]
def main():
    node = 'news'   # 크롤링 할 대상
    srcText = input('검색어를 입력하세요: ')
    cnt = 0
    jsonResult = []

    jsonResponse = getNaverSearch(node, srcText, 1, 100)  #[CODE 2]
    total = jsonResponse['total']
 
    while ((jsonResponse != None) and (jsonResponse['display'] != 0)):         
        for post in jsonResponse['items']:
            cnt += 1
            getPostData(post, jsonResult, cnt)  #[CODE 3]       
        
        start = jsonResponse['start'] + jsonResponse['display']
        jsonResponse = getNaverSearch(node, srcText, start, 100)  #[CODE 2]
       
    print('전체 검색 : %d 건' %total)
    
    with open('%s_naver_%s.json' % (srcText, node), 'w', encoding='utf8') as outfile:
        jsonFile = json.dumps(jsonResult,  indent=4, sort_keys=True,  ensure_ascii=False)
                        
        outfile.write(jsonFile)
        
    print("가져온 데이터 : %d 건" %(cnt))
    print ('%s_naver_%s.json SAVED' % (srcText, node))
    
if __name__ == '__main__':
    main()
# Out:
# 검색어를 입력하세요: 플랫폼
# [2023-06-13 10:42:10.058947] Url Request Success
# [2023-06-13 10:42:10.287233] Url Request Success
# [2023-06-13 10:42:10.583465] Url Request Success
# [2023-06-13 10:42:10.782913] Url Request Success
# [2023-06-13 10:42:11.214010] Url Request Success
# [2023-06-13 10:42:11.434491] Url Request Success
# [2023-06-13 10:42:11.800229] Url Request Success
# [2023-06-13 10:42:12.128343] Url Request Success
# [2023-06-13 10:42:12.416058] Url Request Success
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/c8/ktkt9zzj4870kf9xvg7mhkzr0000gn/T/ipykernel_13148/3199898679.py in <module>
#      85
#      86 if __name__ == '__main__':
# ---> 87     main()
#
# /var/folders/c8/ktkt9zzj4870kf9xvg7mhkzr0000gn/T/ipykernel_13148/3199898679.py in main()
#      72
#      73         start = jsonResponse['start'] + jsonResponse['display']
# ---> 74         jsonResponse = getNaverSearch(node, srcText, start, 100)  #[CODE 2]
#      75
#      76     print('전체 검색 : %d 건' %total)
#
# /var/folders/c8/ktkt9zzj4870kf9xvg7mhkzr0000gn/T/ipykernel_13148/3199898679.py in getNaverSearch(node, srcText, start, display)
#      35
#      36     url = base + node + parameters
# ---> 37     responseDecode = getRequestUrl(url)   #[CODE 1]
#      38
#      39     if (responseDecode == None):
#
# /var/folders/c8/ktkt9zzj4870kf9xvg7mhkzr0000gn/T/ipykernel_13148/3199898679.py in getRequestUrl(url)
#      19
#      20     try:
# ---> 21         response = urllib.request.urlopen(req)
#      22         if response.getcode() == 200:
#      23             print ("[%s] Url Request Success" % datetime.datetime.now())
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1344         try:
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1283                 encode_chunked=False):
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#    1287     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1329             # default charset of iso-8859-1.
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#    1333     def getresponse(self):
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1278         else:
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#    1282     def request(self, method, url, body=None, headers={}, *,
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1038         msg = b"\r\n".join(self._buffer)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#    1042         if message_body is not None:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in send(self, data)
#     978         if self.sock is None:
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#     982                 raise NotConnected()
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in connect(self)
#    1445             "Connect to a host on a given (SSL) port."
#    1446
# -> 1447             super().connect()
#    1448
#    1449             if self._tunnel_host:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in connect(self)
#     944     def connect(self):
#     945         """Connect to the host and port specified in __init__."""
# --> 946         self.sock = self._create_connection(
#     947             (self.host,self.port), self.timeout, self.source_address)
#     948         # Might fail in OSs that don't implement TCP_NODELAY
#
# ~/opt/anaconda3/lib/python3.9/socket.py in create_connection(address, timeout, source_address)
#     830             if source_address:
#     831                 sock.bind(source_address)
# --> 832             sock.connect(sa)
#     833             # Break explicitly a reference cycle
#     834             err = None
#
# KeyboardInterrupt:

# %%
import requests

url = 'http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList'
params ={'serviceKey' : '/H1gjQ0RIdraQdnpqe1aV+T34G1zGrDy1Zwb0PSh0Shg6Qytr2cekv4KuuHXxDJpDUiABfWTLGQRy+dywBVn+g==', 'YM' : '201201', 'NAT_CD' : '112', 'ED_CD' : 'E' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>0000</resultCode><resultMsg>OK</resultMsg></header><body><items><item><ed>\xeb\xb0\xa9\xed\x95\x9c\xec\x99\xb8\xeb\x9e\x98\xea\xb4\x80\xea\xb4\x91\xea\xb0\x9d</ed><edCd>E</edCd><natCd>112</natCd><natKorNm>\xec\xa4\x91  \xea\xb5\xad</natKorNm><num>167022</num><rnum>1</rnum><ym>201201</ym></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>'

# %%
#공공데이터 API 기반 크롤링

import os
import sys
import urllib.request
import datetime
import time
import json
import pandas as pd

ServiceKey="%2FH1gjQ0RIdraQdnpqe1aV%2BT34G1zGrDy1Zwb0PSh0Shg6Qytr2cekv4KuuHXxDJpDUiABfWTLGQRy%2BdywBVn%2Bg%3D%3D"

#[CODE 1]
def getRequestUrl(url):    
    req = urllib.request.Request(url)    
    try: 
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print ("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None


#[CODE 2]
def getTourismStatsItem(yyyymm, national_code, ed_cd):    
    service_url = "http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"
    parameters = "?_type=json&serviceKey=" + ServiceKey   #인증키
    parameters += "&YM=" + yyyymm
    parameters += "&NAT_CD=" + national_code
    parameters += "&ED_CD=" + ed_cd
    url = service_url + parameters
    
    retData = getRequestUrl(url)   #[CODE 1]
    
    if (retData == None):
        return None
    else:
         return json.loads(retData)

#[CODE 3]
def getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear):
    jsonResult = []
    result = []
    natName=''
    dataEND = "{0}{1:0>2}".format(str(nEndYear), str(12)) #데이터 끝 초기화 YYYYMM
    isDataEnd = 0 #데이터 끝 확인용 flag 초기화    
    
    for year in range(nStartYear, nEndYear+1):        
        for month in range(1, 13):
            if(isDataEnd == 1): break #데이터 끝 flag 설정되어있으면 작업 중지.
            yyyymm = "{0}{1:0>2}".format(str(year), str(month))            
            jsonData = getTourismStatsItem(yyyymm, nat_cd, ed_cd) #[CODE 2]
            
            if (jsonData['response']['header']['resultMsg'] == 'OK'):               
                # 입력된 범위까지 수집하지 않았지만, 더이상 제공되는 데이터가 없는 마지막 항목인 경우 -------------------
                if jsonData['response']['body']['items'] == '': 
                    isDataEnd = 1 #데이터 끝 flag 설정
                    dataEND = "{0}{1:0>2}".format(str(year), str(month-1))
                    print("데이터 없음.... \n 제공되는 통계 데이터는 %s년 %s월까지입니다."                          
                          %(str(year), str(month-1)))                    
                    break                
                #jsonData를 출력하여 확인......................................................
                print (json.dumps(jsonData, indent=4, 
                         sort_keys=True, ensure_ascii=False))          
                natName = jsonData['response']['body']['items']['item']['natKorNm']
                natName = natName.replace(' ', '')
                num = jsonData['response']['body']['items']['item']['num']
                ed = jsonData['response']['body']['items']['item']['ed']
                print('[ %s_%s : %s ]' %(natName, yyyymm, num))
                print('----------------------------------------------------------------------')                
                jsonResult.append({'nat_name': natName, 'nat_cd': nat_cd,
                                 'yyyymm': yyyymm, 'visit_cnt': num})
                result.append([natName, nat_cd, yyyymm, num])
                
    return (jsonResult, result, natName, ed, dataEND)

#[CODE 0]
def main():
    jsonResult = []
    result = []
    natName=''
    print("<< 국내 입국한 외국인의 통계 데이터를 수집합니다. >>")
    nat_cd = input('국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : ')
    nStartYear =int(input('데이터를 몇 년부터 수집할까요? : '))
    nEndYear = int(input('데이터를 몇 년까지 수집할까요? : '))
    ed_cd = "E"     #E : 방한외래관광객, D : 해외 출국
    
    jsonResult, result, natName, ed, dataEND =getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear) #[CODE 3]

    if (natName=='') : #URL 요청은 성공하였지만, 데이터 제공이 안된 경우
        print('데이터가 전달되지 않았습니다. 공공데이터포털의 서비스 상태를 확인하기 바랍니다.')
    else:
        #파일저장 1 : json 파일       
        with open('./%s_%s_%d_%s.json' % (natName, ed, nStartYear, dataEND), 'w', encoding='utf8') as outfile:
            jsonFile  = json.dumps(jsonResult, indent=4, sort_keys=True, ensure_ascii=False)
            outfile.write(jsonFile)
        #파일저장 2 : csv 파일   
        columns = ["입국자국가", "국가코드", "입국연월", "입국자 수"]
        result_df = pd.DataFrame(result, columns = columns)
        result_df.to_csv('./%s_%s_%d_%s.csv' % (natName, ed, nStartYear, dataEND),
                    index=False, encoding='cp949')
    
if __name__ == '__main__':
    main()
# Out:
# << 국내 입국한 외국인의 통계 데이터를 수집합니다. >>
# 국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : 130
# 데이터를 몇 년부터 수집할까요? : 2020
# 데이터를 몇 년까지 수집할까요? : 2021
# [2023-06-12 21:06:59.154907] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 203969,
#                     "rnum": 1,
#                     "ym": 202001
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202001 : 203969 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.206576] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 211199,
#                     "rnum": 1,
#                     "ym": 202002
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202002 : 211199 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.253095] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 8347,
#                     "rnum": 1,
#                     "ym": 202003
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202003 : 8347 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.301120] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 360,
#                     "rnum": 1,
#                     "ym": 202004
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202004 : 360 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.348785] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 413,
#                     "rnum": 1,
#                     "ym": 202005
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202005 : 413 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.395066] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 498,
#                     "rnum": 1,
#                     "ym": 202006
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202006 : 498 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.440143] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 755,
#                     "rnum": 1,
#                     "ym": 202007
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202007 : 755 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.490273] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1275,
#                     "rnum": 1,
#                     "ym": 202008
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202008 : 1275 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.540283] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 794,
#                     "rnum": 1,
#                     "ym": 202009
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202009 : 794 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.587242] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 927,
#                     "rnum": 1,
#                     "ym": 202010
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202010 : 927 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.643105] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1254,
#                     "rnum": 1,
#                     "ym": 202011
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202011 : 1254 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.691356] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 951,
#                     "rnum": 1,
#                     "ym": 202012
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202012 : 951 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.739551] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1299,
#                     "rnum": 1,
#                     "ym": 202101
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202101 : 1299 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.789924] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1719,
#                     "rnum": 1,
#                     "ym": 202102
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202102 : 1719 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.840083] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 949,
#                     "rnum": 1,
#                     "ym": 202103
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202103 : 949 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.888600] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 872,
#                     "rnum": 1,
#                     "ym": 202104
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202104 : 872 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.941508] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1403,
#                     "rnum": 1,
#                     "ym": 202105
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202105 : 1403 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:06:59.992867] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 875,
#                     "rnum": 1,
#                     "ym": 202106
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202106 : 875 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:07:00.040864] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 881,
#                     "rnum": 1,
#                     "ym": 202107
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202107 : 881 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:07:00.093076] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 2258,
#                     "rnum": 1,
#                     "ym": 202108
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202108 : 2258 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:07:00.148146] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1142,
#                     "rnum": 1,
#                     "ym": 202109
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202109 : 1142 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:07:00.201118] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1237,
#                     "rnum": 1,
#                     "ym": 202110
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202110 : 1237 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:07:00.252945] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1623,
#                     "rnum": 1,
#                     "ym": 202111
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202111 : 1623 ]
# ----------------------------------------------------------------------
# [2023-06-12 21:07:00.303139] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1007,
#                     "rnum": 1,
#                     "ym": 202112
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202112 : 1007 ]
# ----------------------------------------------------------------------
